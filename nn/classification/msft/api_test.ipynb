# %%
from huggingface_hub.inference_api import InferenceApi

import numpy as np
import pandas as pd

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.set_option('display.max_colwidth', None)

# %%
def get_classes(row, labels, min_score):
    s = row[labels]
    s = s.sort_values(ascending=False)
    return s[s > min_score].index.values

# %%
def results_to_df(results, labels, sequences, min_score = 0.9):
    nresults = len(results)
    scores = pd.DataFrame(0, index=range(nresults), columns=labels, dtype=float)

    nlabels = len(labels)
    for j in range(nresults):    
        r = results[j]

        for i in range(nlabels):
            scores.loc[j, r['labels'][i]] = r['scores'][i]

    scores['classes'] = scores.apply(lambda s: get_classes(s, labels, min_score), axis=1)
    scores['has_class'] = scores.classes.apply(lambda x: len(x) > 0)
    scores['max_class'] = scores.classes.apply(lambda x: x[0] if len(x) > 0 else None)
    scores['seq'] = sequences
    return scores

# %%
API_TOKEN = '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'
inference = InferenceApi(repo_id="facebook/bart-large-mnli", token=API_TOKEN)

# %%
sequences_to_classify = ["one day I will see the world", "best steak in america"]
candidate_labels = ['travel', 'cooking', 'dancing', 'exploration']

# %%
cols = open("videostoingest_cols.txt").readlines()
cols = [c.strip() for c in cols]
print(cols)

vd = pd.read_csv('VideosToIngest_2022-09-01.tsv', sep='\t', header=None, names=cols)
# Out:
# ['VideoKey', 'VideoId', 'VideoUrl', 'ChannelName', 'ChannelId', 'Description', 'Title', 'PlayerType', 'PlayerParams', 'ProductsJson', 'ChannelImage', 'Status', 'StartTimeInMillis', 'DurationInSeconds', 'ThumbnailUrl', 'TrailerUrl', 'Tags', 'MinPrice', 'ViewCount', 'Market', 'ChannelKey', 'PartnerAlias', 'StreamingType', 'StreamingUrl']

# %%
samples = vd[:5]

# %%
desc = list(samples.Description.values)
titles = list(samples.Title.values)

# %%
candidate_labels = ['travel', 'food', 'kitchen', 'home improvement',  'home decor', 'home furnishings', 'apparel', 'shoes', 'lawn and garden', 'computing', 'electronics', 'art and craft', 'photography', 'storage', 'organization', 'pets', 'baby', 'kids', 'music', 'car and garage', 'toys', 'tools and hardware', 'jewelry and watches', 'sports', 'outdoor', 'books and magazines', 'health', 'beauty', 'fragrance', 'productivity', 'office supplies', 'holiday', 'deals', 'review']
len(candidate_labels)
# Out:
# 34

# %%
sel_labels = candidate_labels[:10]

# %%
params = {"candidate_labels": sel_labels, "multi_label": True}

# %%
results_bart = inference(titles, params)

# %%
results_bart
# Out:
# [{'sequence': 'TOP TEN LARGE WALL ART DIY IDEAS | DIY IKEA HACK | AFFORDABLE & AESTHETIC',
#   'labels': ['home decor',
#    'home improvement',
#    'home furnishings',
#    'computing',
#    'kitchen',
#    'travel',
#    'apparel',
#    'shoes',
#    'food',
#    'lawn and garden'],
#   'scores': [0.07297678291797638,
#    0.05170673877000809,
#    0.026421133428812027,
#    0.0014238181756809354,
#    0.001409256481565535,
#    0.0005605021142400801,
#    0.00033417652593925595,
#    0.00015858169354032725,
#    0.00012850352504756302,
#    0.00010840879986062646]},
#  {'sequence': 'TOP 20 DIY DOLLAR TREE FALL HOME DECOR COMPILATION 2022 | HIGH END & NOT CHEESY FALL DECOR',
#   'labels': ['home decor',
#    'home improvement',
#    'home furnishings',
#    'computing',
#    'kitchen',
#    'travel',
#    'food',
#    'apparel',
#    'lawn and garden',
#    'shoes'],
#   'scores': [0.9959635734558105,
#    0.8865137696266174,
#    0.8708468079566956,
#    0.5940498113632202,
#    0.15482766926288605,
#    0.0009228277485817671,
#    0.00046548040700145066,
#    0.0003099004679825157,
#    0.00015218973567243665,
#    7.849522808101028e-05]},
#  {'sequence': 'DIY IKEA HACKS | AFFORDABLE, AESTHETIC, AND SUPER EASY 2022',
#   'labels': ['home furnishings',
#    'home improvement',
#    'kitchen',
#    'home decor',
#    'lawn and garden',
#    'computing',
#    'travel',
#    'apparel',
#    'food',
#    'shoes'],
#   'scores': [0.9566057920455933,
#    0.6199386715888977,
#    0.5058633685112,
#    0.4473886489868164,
#    0.026142092421650887,
#    0.01816781982779503,
#    0.0007880800403654575,
#    0.00077829509973526,
#    0.0004097155760973692,
#    0.0002425130660412833]},
#  {'sequence': 'THRIFT WITH ME FOR HIGH END HOME DECOR | DIY THRIFT FLIP ROOM DECOR + HUGE DECOR THRIFT HAUL',
#   'labels': ['home decor',
#    'home furnishings',
#    'home improvement',
#    'kitchen',
#    'computing',
#    'apparel',
#    'travel',
#    'food',
#    'shoes',
#    'lawn and garden'],
#   'scores': [0.9978652596473694,
#    0.9951918125152588,
#    0.989791750907898,
#    0.16378994286060333,
#    0.0013454295694828033,
#    0.00031664466951042414,
#    0.00017129610932897776,
#    0.00013438027235679328,
#    0.00011213294055778533,
#    7.354523404501379e-05]},
#  {'sequence': 'TOP 22 THRIFTED HOME DECOR FINDS | DIY THRIFTED HOME DECOR COMPILATION',
#   'labels': ['home decor',
#    'home furnishings',
#    'home improvement',
#    'kitchen',
#    'lawn and garden',
#    'computing',
#    'travel',
#    'apparel',
#    'shoes',
#    'food'],
#   'scores': [0.9934711456298828,
#    0.9507697820663452,
#    0.6710869669914246,
#    0.40299463272094727,
#    0.16670037806034088,
#    0.08172640949487686,
#    0.019479652866721153,
#    0.005256414879113436,
#    0.0020185806788504124,
#    0.0007429125835187733]}]

# %%
df_bart = results_to_df(results_bart, labels=sel_labels, sequences=titles)

# %%
df_bart
# Out:
#      travel      food   kitchen  home improvement  home decor  \
# 0  0.000561  0.000129  0.001409          0.051707    0.072977
# 1  0.000923  0.000465  0.154828          0.886514    0.995964
# 2  0.000788  0.000410  0.505863          0.619939    0.447389
# 3  0.000171  0.000134  0.163790          0.989792    0.997865
# 4  0.019480  0.000743  0.402995          0.671087    0.993471
#
#    home furnishings   apparel     shoes  lawn and garden  computing  \
# 0          0.026421  0.000334  0.000159         0.000108   0.001424
# 1          0.870847  0.000310  0.000078         0.000152   0.594050
# 2          0.956606  0.000778  0.000243         0.026142   0.018168
# 3          0.995192  0.000317  0.000112         0.000074   0.001345
# 4          0.950770  0.005256  0.002019         0.166700   0.081726
#
#                                             classes  has_class  \
# 0                                                []      False
# 1                                      [home decor]       True
# 2                                [home furnishings]       True
# 3  [home decor, home furnishings, home improvement]       True
# 4                    [home decor, home furnishings]       True
#
#           max_class  \
# 0              None
# 1        home decor
# 2  home furnishings
# 3        home decor
# 4        home decor
#
#                                                                                             seq
# 0                     TOP TEN LARGE WALL ART DIY IDEAS | DIY IKEA HACK | AFFORDABLE & AESTHETIC
# 1    TOP 20 DIY DOLLAR TREE FALL HOME DECOR COMPILATION 2022 | HIGH END & NOT CHEESY FALL DECOR
# 2                                   DIY IKEA HACKS | AFFORDABLE, AESTHETIC, AND SUPER EASY 2022
# 3  THRIFT WITH ME FOR HIGH END HOME DECOR | DIY THRIFT FLIP ROOM DECOR + HUGE DECOR THRIFT HAUL
# 4                        TOP 22 THRIFTED HOME DECOR FINDS | DIY THRIFTED HOME DECOR COMPILATION

# %%
inference_distilbert = InferenceApi(repo_id="typeform/distilbert-base-uncased-mnli", token=API_TOKEN)

# %%
results = inference_distilbert(titles, params)

# %%
df_distilbert = results_to_df(results, labels=candidate_labels[:10], sequences=titles)

# %%
df_distilbert
# Out:
#      travel      food   kitchen  home improvement  home decor  \
# 0  0.000040  0.000048  0.000046          0.001367    0.000087
# 1  0.000068  0.000119  0.000074          0.619678    0.720001
# 2  0.000064  0.001197  0.000113          0.934864    0.814112
# 3  0.011940  0.070653  0.000082          0.714349    0.995737
# 4  0.000165  0.000690  0.000188          0.720730    0.999655
# 5  0.017835  0.002699  0.000130          0.513331    0.591688
# 6  0.000063  0.000102  0.000126          0.672213    0.977235
# 7  0.000065  0.000219  0.000222          0.997691    0.977955
# 8  0.000132  0.000105  0.000092          0.000422    0.011346
# 9  0.991687  0.000063  0.000117          0.594497    0.001018
#
#    home furnishings   apparel     shoes  lawn and garden  computing  \
# 0          0.000087  0.002411  0.000042         0.000112   0.000044
# 1          0.984961  0.124405  0.000132         0.064587   0.000080
# 2          0.989971  0.991312  0.000068         0.284580   0.100804
# 3          0.997555  0.215293  0.005084         0.016319   0.001104
# 4          0.999840  0.011078  0.000240         0.275992   0.019098
# 5          0.666838  0.831846  0.005460         0.012879   0.348965
# 6          0.998470  0.007537  0.000069         0.400024   0.000117
# 7          0.999222  0.278022  0.004304         0.927216   0.160939
# 8          0.974358  0.029242  0.000123         0.120526   0.090578
# 9          0.156248  0.396392  0.001004         0.099121   0.172997
#
#                                                              classes  \
# 0                                                                 []
# 1                                                 [home furnishings]
# 2                      [apparel, home furnishings, home improvement]
# 3                                     [home furnishings, home decor]
# 4                                     [home furnishings, home decor]
# 5                                                                 []
# 6                                     [home furnishings, home decor]
# 7  [home furnishings, home improvement, home decor, lawn and garden]
# 8                                                 [home furnishings]
# 9                                                           [travel]
#
#    has_class         max_class  \
# 0      False              None
# 1       True  home furnishings
# 2       True           apparel
# 3       True  home furnishings
# 4       True  home furnishings
# 5      False              None
# 6       True  home furnishings
# 7       True  home furnishings
# 8       True  home furnishings
# 9       True            travel
#
#                                                                                               seq
# 0                       TOP TEN LARGE WALL ART DIY IDEAS | DIY IKEA HACK | AFFORDABLE & AESTHETIC
# 1      TOP 20 DIY DOLLAR TREE FALL HOME DECOR COMPILATION 2022 | HIGH END & NOT CHEESY FALL DECOR
# 2                                     DIY IKEA HACKS | AFFORDABLE, AESTHETIC, AND SUPER EASY 2022
# 3    THRIFT WITH ME FOR HIGH END HOME DECOR | DIY THRIFT FLIP ROOM DECOR + HUGE DECOR THRIFT HAUL
# 4                          TOP 22 THRIFTED HOME DECOR FINDS | DIY THRIFTED HOME DECOR COMPILATION
# 5              DECORATE WITH ME FOR FALL | DIY THRIFT FLIPS + HUGE FALL INSPIRED THRIFT HAUL 2022
# 6                                                          DIY THRIFT FLIP HOME DECOR ON A BUDGET
# 7  New Most Affordable Indoor and Outdoor Home Lighting?! Inlight Collection Unboxing and Install
# 8                                                                    HOW TO: 90'S BLOWOUT AT HOME
# 9                                                     Desk Tour 2022: Minimal Work & Gaming Setup
